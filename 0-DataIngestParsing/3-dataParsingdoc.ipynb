# %% [markdown]
# ### Word document processing

# %%
from docx import Document as Document
import os

# %%
from langchain_community.document_loaders import Docx2txtLoader,UnstructuredWordDocumentLoader

# %%
##Method1 :using DocxtxLoader
print("using Docxt2loader")
try:
    docx_loader = Docx2txtLoader("data/word_files/proposal.docx")
    docs = docx_loader.load()
    print(f"loaded {len(docs)} documents")
    print(docs[0].page_content[:100])  # Print first 100 characters of the content
    print(f"metadata : {docs[0].page_content[:200]}")
except Exception as e:
    print(f"Error loading document: {e}")
# Out:
# using Docxt2loader
# loaded 1 documents
# Lorem ipsum
#
#
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nunc ac faucibus odio.
#
#
#
#
# metadata : Lorem ipsum
#
#
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nunc ac faucibus odio.
#
#
#
# Vestibulum neque massa, scelerisque sit amet ligula eu, congue molestie mi. Praesent ut varius sem.

# %%
## Method 2
print("\n Using Unstructured Word Document Loader")
try:
    unstructured_loader = UnstructuredWordDocumentLoader("data/word_files/proposal.docx",mode ="elements")
    unstructured_docs= unstructured_loader.load()

    print(f"Loaded {len(unstructured_docs) } elements")
    for i, doc in enumerate(unstructured_docs[:3]):
        print(f"\nElement{i+1}")
        print(f"Type: {doc.metadata.get("category","unknown")}")
        print(f"Content:{doc.page_content[:100]}....")
except Exception as e:
    print(e)
# Out:
#  Using Unstructured Word Document Loader
# Loaded 23 elements
#
# Element1
# Type: Title
# Content:Lorem ipsum ....
#
# Element2
# Type: ListItem
# Content:Lorem ipsum dolor sit amet, consectetur adipiscing elit. Nunc ac faucibus odio.....
#
# Element3
# Type: NarrativeText
# Content:Vestibulum neque massa, scelerisque sit amet ligula eu, congue molestie mi. Praesent ut varius sem. ....

# %%
unstructured_docs[0]
# Out:
# Document(metadata={'source': 'data/word_files/proposal.docx', 'category_depth': 0, 'file_directory': 'data/word_files', 'filename': 'proposal.docx', 'last_modified': '2025-11-10T02:47:46', 'languages': ['cat'], 'filetype': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document', 'category': 'Title', 'element_id': 'd6a52a52a5cf1c53078873f83ef34263'}, page_content='Lorem ipsum ')
